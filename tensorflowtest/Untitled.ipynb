# %%
import numpy as np

# %%
trained_res = np.load("./ImageNet-ResNet18.npy", encoding="latin1")
trained_res = trained_res.item()

for k in trained_res.keys():
    print(k)

print(trained_res['group0/block1/conv2/W:0'])
# Out:
# group0/block0/conv1/bn/variance/EMA:0
# conv0/W:0
# group0/block1/conv2/W:0
# group2/block0/conv1/bn/gamma:0
# bnlast/bn/mean/EMA:0
# group0/block0/conv1/bn/gamma:0
# group0/block1/conv1/W:0
# group3/block0/preact/bn/variance/EMA:0
# group1/block1/conv2/W:0
# conv0/bn/variance/EMA:0
# group0/block0/conv2/W:0
# group3/block0/preact/bn/mean/EMA:0
# group3/block0/conv1/W:0
# group0/block1/preact/bn/variance/EMA:0
# group3/block1/conv1/W:0
# group3/block0/conv1/bn/mean/EMA:0
# group2/block1/conv1/W:0
# group1/block0/conv1/W:0
# group2/block0/preact/bn/mean/EMA:0
# group2/block1/conv1/bn/variance/EMA:0
# group0/block1/preact/bn/mean/EMA:0
# group3/block1/conv1/bn/variance/EMA:0
# group0/block1/preact/bn/gamma:0
# group1/block1/conv1/bn/mean/EMA:0
# group0/block1/conv1/bn/variance/EMA:0
# group1/block0/conv1/bn/variance/EMA:0
# group3/block0/conv1/bn/variance/EMA:0
# group3/block1/preact/bn/mean/EMA:0
# group0/block1/preact/bn/beta:0
# group2/block1/preact/bn/gamma:0
# ...
